# %%
import os
import shutil
import yaml
from glob import glob
from ultralytics import YOLO
from roboflow import Roboflow

# --- 1. 기본 경로 및 최종 설정 ---
# --------------------------------------------------------------------------
# (사용자 확인 필요)
# --------------------------------------------------------------------------
# 모든 데이터셋과 결과가 저장될 상위 폴더 경로
BASE_DATA_PATH = 'C:/Users/Admin/work space/2nd/'

# Roboflow API 키
ROBOFLOW_API_KEY = "NjIXpou4o4gsuGClT8hI"

# 추가 학습을 시작할 모델 경로 (현재까지 가장 성능이 좋았던 modeling2의 결과)
PREVIOUS_MODEL_PATH = os.path.join(BASE_DATA_PATH, 'acne_model_8_classes_retrained', 'weights', 'best.pt')
# --------------------------------------------------------------------------

# --- 모든 데이터셋 정보 ---
# 기존 데이터셋
DATASET1_NAME = 'acne04-1'
DATASET2_NAME = 'Acne-detection-1'
# 추가 데이터셋 1
ROBOFLOW_WORKSPACE_3 = "acne-dqmyr"
ROBOFLOW_PROJECT_3 = "acne-detection-hjgkp"
ROBOFLOW_VERSION_3 = 9
DATASET3_NAME = f"{ROBOFLOW_PROJECT_3}-{ROBOFLOW_VERSION_3}"
# 추가 데이터셋 2
ROBOFLOW_WORKSPACE_4 = "test-l2t0m"
ROBOFLOW_PROJECT_4 = "acne-detection-nv9i6-ddxoy"
ROBOFLOW_VERSION_4 = 1
DATASET4_NAME = f"{ROBOFLOW_PROJECT_4}-{ROBOFLOW_VERSION_4}"

# --- 최종 결과 폴더 이름 설정 ---
COMBINED_DATASET_NAME = 'acne_dataset_final_ALL'
TRAINING_NAME = 'acne_model_final_ALL'

# %%
# --- 2. 새로운 Roboflow 데이터셋 다운로드 (필요시) ---
print("🚀 Roboflow 데이터셋 다운로드를 시작합니다...")
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
# 데이터셋 3 다운로드
if not os.path.exists(os.path.join(BASE_DATA_PATH, DATASET3_NAME)):
    print(f"\n[1/2] '{DATASET3_NAME}' 데이터셋을 다운로드합니다...")
    project3 = rf.workspace(ROBOFLOW_WORKSPACE_3).project(ROBOFLOW_PROJECT_3)
    version3 = project3.version(ROBOFLOW_VERSION_3)
    version3.download("yolov11", location=BASE_DATA_PATH)
    print("✅ 다운로드 완료!")
else:
    print(f"\n[1/2] '{DATASET3_NAME}' 데이터셋이 이미 존재하여 다운로드를 건너뜁니다.")

# 데이터셋 4 다운로드
if not os.path.exists(os.path.join(BASE_DATA_PATH, DATASET4_NAME)):
    print(f"\n[2/2] '{DATASET4_NAME}' 데이터셋을 다운로드합니다...")
    project4 = rf.workspace(ROBOFLOW_WORKSPACE_4).project(ROBOFLOW_PROJECT_4)
    version4 = project4.version(ROBOFLOW_VERSION_4)
    version4.download("yolov11", location=BASE_DATA_PATH)
    print("✅ 다운로드 완료!")
else:
    print(f"\n[2/2] '{DATASET4_NAME}' 데이터셋이 이미 존재하여 다운로드를 건너뜁니다.")
print("-" * 50)
# Out:
# 🚀 Roboflow 데이터셋 다운로드를 시작합니다...
#
# [1/2] 'acne-detection-hjgkp-9' 데이터셋을 다운로드합니다...
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ 다운로드 완료!
#
# [2/2] 'acne-detection-nv9i6-ddxoy-1' 데이터셋을 다운로드합니다...
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ 다운로드 완료!
# --------------------------------------------------

# %%
# --- 3. 클래스 목록 정의 및 중복 클래스 확인 (수정된 경로 사용) ---
FINAL_CLASS_NAMES = sorted(['blackheads', 'comedone', 'cyst', 'fore', 'nodule', 'papule', 'pustule', 'whiteheads'])
final_class_set = set(FINAL_CLASS_NAMES)

def get_overlapping_classes(dataset_path, dataset_name):
    yaml_path = os.path.join(dataset_path, 'data.yaml')
    class_names = []
    if os.path.exists(yaml_path):
        with open(yaml_path, 'r', encoding='utf-8') as f:
            yaml_data = yaml.safe_load(f)
            class_names = yaml_data.get('names', [])
    
    overlapping = sorted(list(final_class_set.intersection(set(class_names))))
    
    print(f"\n--- {dataset_name} 클래스 정보 ---")
    print(f"전체 클래스: {class_names}")
    print(f"✅ 중복 클래스: {overlapping}")
    return class_names, overlapping

# ❗️❗️❗️[버그 수정]❗️❗️❗️ Roboflow 다운로드 폴더 경로를 직접 구성하여 정확하게 지정
src_path_d3_corrected = os.path.join(BASE_DATA_PATH, DATASET3_NAME)
src_path_d4_corrected = os.path.join(BASE_DATA_PATH, DATASET4_NAME)

d3_names, overlapping_d3 = get_overlapping_classes(src_path_d3_corrected, "데이터셋 3")
d4_names, overlapping_d4 = get_overlapping_classes(src_path_d4_corrected, "데이터셋 4")
print("-" * 50)
# Out:
# --- 데이터셋 3 클래스 정보 ---
# 전체 클래스: []
# ✅ 중복 클래스: []
#
# --- 데이터셋 4 클래스 정보 ---
# 전체 클래스: []
# ✅ 중복 클래스: []
# --------------------------------------------------

# %%
# --- 4. 클래스 ID 재매핑 테이블 생성 ---
final_name_to_id = {name: i for i, name in enumerate(FINAL_CLASS_NAMES)}
# 기존 데이터셋 매핑
ORIGINAL_D1_NAMES = ['fore', 'papule', 'pustule', 'nodule', 'whiteheads', 'cyst', 'blackheads']
remap_d1 = {i: final_name_to_id[name] for i, name in enumerate(ORIGINAL_D1_NAMES)}
ORIGINAL_D2_NAMES = ['comedone', 'pustule', 'papule', 'cyst', 'nodule']
remap_d2 = {i: final_name_to_id[name] for i, name in enumerate(ORIGINAL_D2_NAMES)}
# 추가 데이터셋 매핑
id_to_name_d3 = {i: name for i, name in enumerate(d3_names)}
remap_d3 = {i: final_name_to_id[name] for i, name in enumerate(d3_names) if name in overlapping_d3}
id_to_name_d4 = {i: name for i, name in enumerate(d4_names)}
remap_d4 = {i: final_name_to_id[name] for i, name in enumerate(d4_names) if name in overlapping_d4}

# %%
# --- 5. 데이터 병합 및 라벨 재매핑 실행 ---
src_path_d1 = os.path.join(BASE_DATA_PATH, DATASET1_NAME)
src_path_d2 = os.path.join(BASE_DATA_PATH, DATASET2_NAME)
combined_path = os.path.join(BASE_DATA_PATH, COMBINED_DATASET_NAME)

if os.path.exists(combined_path):
    shutil.rmtree(combined_path)
print(f"'{combined_path}' 폴더를 생성하고 4개 데이터셋 병합을 시작합니다...")

def process_dataset(src_path, remap_dict, dest_path, classes_to_keep=None, id_to_name_map=None):
    for split in ['train', 'valid', 'test']:
        src_image_dir = os.path.join(src_path, split, 'images')
        src_label_dir = os.path.join(src_path, split, 'labels')
        if not os.path.exists(src_image_dir): continue

        dest_image_dir = os.path.join(dest_path, split, 'images')
        dest_label_dir = os.path.join(dest_path, split, 'labels')
        os.makedirs(dest_image_dir, exist_ok=True)
        os.makedirs(dest_label_dir, exist_ok=True)

        for label_filename in glob(os.path.join(src_label_dir, '*.txt')):
            # ... (이하 함수 내용은 동일)
            base_filename = os.path.basename(label_filename)
            with open(label_filename, 'r') as f_in: lines = f_in.readlines()
            new_lines = []
            for line in lines:
                parts = line.strip().split();
                if not parts: continue
                original_id = int(parts[0])
                if classes_to_keep and id_to_name_map:
                    if id_to_name_map.get(original_id) not in classes_to_keep: continue
                if original_id in remap_dict:
                    parts[0] = str(remap_dict[original_id])
                    new_lines.append(' '.join(parts) + '\n')
            if new_lines:
                with open(os.path.join(dest_label_dir, base_filename), 'w') as f_out: f_out.writelines(new_lines)
                img_name_base = os.path.splitext(base_filename)[0]
                for ext in ['.jpg', '.jpeg', '.png']:
                    src_image_path = os.path.join(src_image_dir, img_name_base + ext)
                    if os.path.exists(src_image_path):
                        shutil.copy(src_image_path, os.path.join(dest_image_dir, img_name_base + ext)); break

print("1/4 - 기존 데이터셋 1 처리 중..."); process_dataset(src_path_d1, remap_d1, combined_path)
print("2/4 - 기존 데이터셋 2 처리 중..."); process_dataset(src_path_d2, remap_d2, combined_path)
print("3/4 - 추가 데이터셋 3 처리 중..."); process_dataset(src_path_d3_corrected, remap_d3, combined_path, classes_to_keep=overlapping_d3, id_to_name_map=id_to_name_d3)
print("4/4 - 추가 데이터셋 4 처리 중..."); process_dataset(src_path_d4_corrected, remap_d4, combined_path, classes_to_keep=overlapping_d4, id_to_name_map=id_to_name_d4)
print("✅ 데이터 병합 완료!"); print("-" * 50)
# Out:
# 'C:/Users/Admin/work space/2nd/acne_dataset_final_ALL' 폴더를 생성하고 4개 데이터셋 병합을 시작합니다...
# 1/4 - 기존 데이터셋 1 처리 중...
# 2/4 - 기존 데이터셋 2 처리 중...
# 3/4 - 추가 데이터셋 3 처리 중...
# 4/4 - 추가 데이터셋 4 처리 중...
# ✅ 데이터 병합 완료!
# --------------------------------------------------

# %%
# --- 6. 최종 data.yaml 파일 생성 ---
final_yaml_path = os.path.join(combined_path, 'data.yaml')
yaml_data = {'train': 'train/images', 'val': 'valid/images', 'test': 'test/images', 'nc': len(FINAL_CLASS_NAMES), 'names': FINAL_CLASS_NAMES}
with open(final_yaml_path, 'w', encoding='utf-8') as f:
    yaml.dump(yaml_data, f, allow_unicode=True, sort_keys=False)
print(f"✅ 최종 '{final_yaml_path}' 파일 생성 완료!"); print("-" * 50)
# Out:
# ✅ 최종 'C:/Users/Admin/work space/2nd/acne_dataset_final_ALL\data.yaml' 파일 생성 완료!
# --------------------------------------------------

# %%
# --- 7. 최종 모델 추가 학습 (Fine-tuning) ---
if not os.path.exists(PREVIOUS_MODEL_PATH):
     print(f"🚨 에러: 이전 모델 '{PREVIOUS_MODEL_PATH}'를 찾을 수 없습니다.")
else:
    print(f"🚀 이전 최강 모델 '{PREVIOUS_MODEL_PATH}'을 불러와 최종 학습을 시작합니다...")
    model = YOLO(PREVIOUS_MODEL_PATH)
    results = model.train(
        data=final_yaml_path,
        epochs=250,      # 더 많은 데이터로 학습하므로 epochs 증가 고려
        imgsz=640,
        batch=16,
        patience=50,
        project=BASE_DATA_PATH,
        name=TRAINING_NAME,
        workers=4,
        cache=True       # 데이터셋이 크므로 캐시 사용 권장
    )
    print(f"\n🎉 최종 학습 완료! 결과 저장 경로: {os.path.join(BASE_DATA_PATH, TRAINING_NAME)}")
# Out:
# 🚀 이전 최강 모델 'C:/Users/Admin/work space/2nd/acne_model_8_classes_retrained\weights\best.pt'을 불러와 최종 학습을 시작합니다...
# New https://pypi.org/project/ultralytics/8.3.202 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:/Users/Admin/work space/2nd/acne_dataset_final_ALL\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=250, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=C:/Users/Admin/work space/2nd/acne_model_8_classes_retrained\weights\best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=acne_model_final_ALL2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:/Users/Admin/work space/2nd/, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Admin\work space\2nd\acne_model_final_ALL2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752872  ultralytics.nn.modules.head.Detect           [8, [64, 128, 256]]
# Model summary: 129 layers, 3,012,408 parameters, 3,012,392 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 959.51001.3 MB/s, size: 320.3 KB)
# train: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final_ALL\train\labels.cache... 632 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 632/632 562.9Kit/s 0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 2833. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.6GB RAM): 100% ━━━━━━━━━━━━ 632/632 258.5it/s 2.4s0.2s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.10.0 ms, read: 33.119.8 MB/s, size: 12.7 KB)
# val: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final_ALL\valid\labels.cache... 124 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 124/124 43.1Kit/s 0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 124/124 143.7it/s 0.9s0.2s
# Plotting labels to C:\Users\Admin\work space\2nd\acne_model_final_ALL2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to C:\Users\Admin\work space\2nd\acne_model_final_ALL2
# Starting training for 250 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/250      2.99G      1.453     0.9711      1.168         38        640: 100% ━━━━━━━━━━━━ 40/40 4.6it/s 8.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.0it/s 1.0s0.4s
#                    all        124        615      0.564       0.48      0.502      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/250      2.99G      1.497      1.058      1.216         65        640: 100% ━━━━━━━━━━━━ 40/40 5.5it/s 7.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.6s0.6s
#                    all        124        615      0.593      0.499      0.474       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/250      3.22G      1.527      1.076      1.238         51        640: 100% ━━━━━━━━━━━━ 40/40 5.1it/s 7.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.5s
#                    all        124        615      0.498      0.462      0.461      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/250      3.22G      1.573      1.134      1.254         31        640: 100% ━━━━━━━━━━━━ 40/40 4.5it/s 9.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s0.5s
#                    all        124        615      0.564       0.48      0.478      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/250      3.45G      1.598      1.133      1.252         48        640: 100% ━━━━━━━━━━━━ 40/40 5.0it/s 8.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s0.4s
#                    all        124        615      0.563      0.449       0.46      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/250      3.73G      1.567      1.095       1.23         98        640: 100% ━━━━━━━━━━━━ 40/40 4.6it/s 8.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s0.5s
#                    all        124        615      0.479       0.46      0.422       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/250      3.74G      1.565      1.108       1.23        106        640: 100% ━━━━━━━━━━━━ 40/40 5.2it/s 7.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.9it/s 1.4s0.5s
#                    all        124        615      0.482      0.434      0.415      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/250      3.74G      1.607      1.145      1.238         26        640: 100% ━━━━━━━━━━━━ 40/40 4.5it/s 8.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s0.6s
#                    all        124        615      0.506      0.471      0.425       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/250      3.75G      1.597      1.146      1.278         64        640: 100% ━━━━━━━━━━━━ 40/40 5.0it/s 8.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s0.5s
#                    all        124        615      0.537      0.344      0.411       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/250      3.76G        1.6      1.132      1.242         39        640: 100% ━━━━━━━━━━━━ 40/40 6.2it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.9it/s 0.7s0.3s
#                    all        124        615      0.461      0.408       0.42      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/250      3.77G      1.563      1.079      1.254         21        640: 100% ━━━━━━━━━━━━ 40/40 7.3it/s 5.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.2it/s 0.8s0.3s
#                    all        124        615      0.518      0.432       0.45      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/250      3.78G      1.583      1.132      1.245         39        640: 100% ━━━━━━━━━━━━ 40/40 7.2it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.2it/s 0.8s0.3s
#                    all        124        615      0.621      0.395       0.44      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/250      3.79G      1.601      1.128      1.247        114        640: 100% ━━━━━━━━━━━━ 40/40 6.7it/s 6.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.5it/s 0.7s0.3s
#                    all        124        615      0.417      0.398      0.393      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/250       3.8G      1.537      1.066      1.236         95        640: 100% ━━━━━━━━━━━━ 40/40 7.7it/s 5.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 6.1it/s 0.7s0.3s
#                    all        124        615      0.502      0.466      0.434      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/
0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/250      3.81G      1.367     0.8728      1.137         20        640: 100% ━━━━━━━━━━━━ 40/40 7.6it/s 5.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.9it/s 0.7s0.3s
#                    all        124        615      0.573      0.423      0.445      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/250      3.81G      1.315     0.8465      1.117         27        640: 100% ━━━━━━━━━━━━ 40/40 7.6it/s 5.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.6it/s 0.7s0.3s
#                    all        124        615      0.495      0.518      0.461      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/250      3.81G      1.331     0.8508      1.104         79        640: 100% ━━━━━━━━━━━━ 40/40 7.5it/s 5.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.5it/s 0.7s0.3s
#                    all        124        615      0.551      0.448      0.468      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/250      3.81G      1.311     0.8494      1.141         19        640: 100% ━━━━━━━━━━━━ 40/40 6.7it/s 6.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.3it/s 0.9s0.3s
#                    all        124        615      0.587      0.388      0.446      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/250      3.81G      1.319     0.8475      1.129         86        640: 100% ━━━━━━━━━━━━ 40/40 5.9it/s 6.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.1it/s 1.0s0.4s
#                    all        124        615      0.519      0.465      0.441      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/250      3.81G       1.33     0.8618      1.123         86        640: 100% ━━━━━━━━━━━━ 40/40 5.4it/s 7.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s0.4s
#                    all        124        615      0.585       0.42      0.468      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/250      4.12G      1.314     0.8339      1.114         50        640: 100% ━━━━━━━━━━━━ 40/40 5.1it/s 7.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 6.1it/s 0.7s0.3s
#                    all        124        615      0.509      0.439      0.436      0.174
# EarlyStopping: Training stopped early as no improvement observed in last 50 epochs. Best results observed at epoch 41, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 91 epochs completed in 0.214 hours.
# Optimizer stripped from C:\Users\Admin\work space\2nd\acne_model_final_ALL2\weights\last.pt, 6.3MB
# Optimizer stripped from C:\Users\Admin\work space\2nd\acne_model_final_ALL2\weights\best.pt, 6.3MB
#
# Validating C:\Users\Admin\work space\2nd\acne_model_final_ALL2\weights\best.pt...
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.1s0.4s
#                    all        124        615      0.537      0.448      0.461      0.198
#               comedone         31         96      0.734      0.488       0.53      0.209
#                   cyst         18         20      0.542       0.75      0.654      0.292
#                 nodule         28         35      0.582      0.457      0.476      0.253
#                 papule         33        419       0.55      0.501      0.506      0.184
#                pustule         11         20      0.632       0.45      0.536      0.237
#             whiteheads          9         25      0.182       0.04     0.0607     0.0136
# Speed: 0.2ms preprocess, 1.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to C:\Users\Admin\work space\2nd\acne_model_final_ALL2
#
# 🎉 최종 학습 완료! 결과 저장 경로: C:/Users/Admin/work space/2nd/acne_model_final_ALL

# %%
   # --- 8. 최종 모델 성능 검증 ---
print("\n🚀 테스트 데이터셋으로 최종 모델 성능을 검증합니다...")
best_model_path = os.path.join(BASE_DATA_PATH, TRAINING_NAME, 'weights', 'best.pt')
if os.path.exists(best_model_path):
        model = YOLO(best_model_path)
        metrics = model.val(data=final_yaml_path, split='test', imgsz=640)
        print("\n--- 최종 성능 지표 ---")
        print(f"mAP50-95: {metrics.box.map:.4f}")
        print(f"mAP50: {metrics.box.map50:.4f}")
        print(f"mAP75: {metrics.box.map75:.4f}")
# Out:
# 🚀 테스트 데이터셋으로 최종 모델 성능을 검증합니다...
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 576.2894.6 MB/s, size: 200.2 KB)
# val: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final_ALL\test\labels.cache... 88 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 88/88 149.9Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 10.6s0.4s
#                    all         88        461      0.529      0.357      0.377      0.162
#               comedone         24         86      0.702      0.466      0.518      0.204
#                   cyst         18         19      0.675      0.549      0.574      0.294
#                 nodule         19         19      0.615      0.526      0.557      0.253
#                 papule         18        264      0.485      0.407      0.384      0.142
#                pustule         10         44      0.413     0.0909       0.11     0.0467
#             whiteheads          7         29      0.283      0.103      0.119     0.0302
# Speed: 4.1ms preprocess, 7.4ms inference, 0.0ms loss, 16.1ms postprocess per image
# Results saved to C:\Users\Admin\work space\2nd\runs\detect\val13
#
# --- 최종 성능 지표 ---
# mAP50-95: 0.1617
# mAP50: 0.3770
# mAP75: 0.1024
