# %%
import os
import shutil
import yaml
from glob import glob
from collections import Counter
from ultralytics import YOLO

# %%
# --- 1. 기본 경로 설정 ---
# 이전에 다운로드한 두 데이터셋의 상위 폴더 경로를 정확하게 지정해주세요.
# 예: 'C:/Users/Admin/work space/2nd/'
BASE_DATA_PATH = 'C:/Users/Admin/work space/2nd/'

# Roboflow에서 다운로드했을 때 생성된 폴더 이름
# (필요시 실제 폴더 이름으로 수정)
DATASET1_NAME = 'acne04-1'
DATASET2_NAME = 'Acne-detection-1'

# %%
# 최종 데이터셋이 저장될 폴더 이름
COMBINED_DATASET_NAME = 'acne_dataset_final'

# %%
# --- 2. 클래스 목록 정의 ---
# 이전 단계에서 확인된 각 데이터셋의 실제 클래스 목록
ORIGINAL_D1_NAMES = ['fore', 'papule', 'pustule', 'nodule', 'whiteheads', 'cyst', 'blackheads']
ORIGINAL_D2_NAMES = ['comedone', 'pustule', 'papule', 'cyst', 'nodule']

# 두 목록을 합치고 중복을 제거한 뒤, 알파벳 순으로 정렬하여 최종 클래스 목록 생성
final_class_set = set(ORIGINAL_D1_NAMES) | set(ORIGINAL_D2_NAMES)
FINAL_CLASS_NAMES = sorted(list(final_class_set))

print("✅ 최종 통합 클래스 목록 (총 {}개):".format(len(FINAL_CLASS_NAMES)))
print(FINAL_CLASS_NAMES)
print("-" * 50)
# Out:
# ✅ 최종 통합 클래스 목록 (총 8개):
# ['blackheads', 'comedone', 'cyst', 'fore', 'nodule', 'papule', 'pustule', 'whiteheads']
# --------------------------------------------------

# %%
# --- 3. 클래스 ID 재매핑 테이블 생성 ---
# 최종 클래스 이름을 기준으로 새로운 ID 부여 (name -> id)
final_name_to_id = {name: i for i, name in enumerate(FINAL_CLASS_NAMES)}

# 각 데이터셋의 원래 ID를 -> 최종 ID로 변환하는 테이블 생성
# 데이터셋 1 매핑 테이블
original_d1_name_to_id = {name: i for i, name in enumerate(ORIGINAL_D1_NAMES)}
remap_d1 = {orig_id: final_name_to_id[name] for name, orig_id in original_d1_name_to_id.items()}

# 데이터셋 2 매핑 테이블
original_d2_name_to_id = {name: i for i, name in enumerate(ORIGINAL_D2_NAMES)}
remap_d2 = {orig_id: final_name_to_id[name] for name, orig_id in original_d2_name_to_id.items()}

# %%
# --- 4. 데이터 병합 및 라벨 재매핑 실행 ---
src_path_d1 = os.path.join(BASE_DATA_PATH, DATASET1_NAME)
src_path_d2 = os.path.join(BASE_DATA_PATH, DATASET2_NAME)
combined_path = os.path.join(BASE_DATA_PATH, COMBINED_DATASET_NAME)

# 기존에 폴더가 있다면 삭제하고 새로 시작
if os.path.exists(combined_path):
    shutil.rmtree(combined_path)
    print(f"기존 '{combined_path}' 폴더를 삭제했습니다.")

print(f"'{combined_path}' 폴더를 생성하고 데이터 병합을 시작합니다...")

# 데이터셋을 처리하는 함수
def process_dataset(src_path, remap_dict, dest_path):
    for split in ['train', 'valid', 'test']:
        src_label_dir = os.path.join(src_path, split, 'labels')
        src_image_dir = os.path.join(src_path, split, 'images')
        
        dest_label_dir = os.path.join(dest_path, split, 'labels')
        dest_image_dir = os.path.join(dest_path, split, 'images')
        
        os.makedirs(dest_label_dir, exist_ok=True)
        os.makedirs(dest_image_dir, exist_ok=True)
        
        if not os.path.exists(src_label_dir):
            continue

        # 라벨 파일 처리 및 이미지 복사
        for label_filename in os.listdir(src_label_dir):
            if not label_filename.endswith('.txt'):
                continue

            # 라벨 파일 재매핑
            with open(os.path.join(src_label_dir, label_filename), 'r') as f_in:
                lines = f_in.readlines()
            
            with open(os.path.join(dest_label_dir, label_filename), 'w') as f_out:
                for line in lines:
                    parts = line.strip().split()
                    if not parts:
                        continue
                    
                    original_id = int(parts[0])
                    if original_id in remap_dict:
                        parts[0] = str(remap_dict[original_id])
                        f_out.write(' '.join(parts) + '\n')

            # 해당 이미지 파일 복사
            base_filename = os.path.splitext(label_filename)[0]
            for ext in ['.jpg', '.jpeg', '.png']:
                image_filename = base_filename + ext
                src_image_path = os.path.join(src_image_dir, image_filename)
                if os.path.exists(src_image_path):
                    shutil.copy(src_image_path, os.path.join(dest_image_dir, image_filename))
                    break

# 각 데이터셋 처리 실행
process_dataset(src_path_d1, remap_d1, combined_path)
process_dataset(src_path_d2, remap_d2, combined_path)

print("✅ 데이터 병합 및 라벨 재매핑 완료!")
print("-" * 50)
# Out:
# 기존 'C:/Users/Admin/work space/2nd/acne_dataset_final' 폴더를 삭제했습니다.
# 'C:/Users/Admin/work space/2nd/acne_dataset_final' 폴더를 생성하고 데이터 병합을 시작합니다...
# ✅ 데이터 병합 및 라벨 재매핑 완료!
# --------------------------------------------------

# %%
# --- 5. 최종 data.yaml 파일 생성 ---
yaml_path = os.path.join(combined_path, 'data.yaml')

yaml_data = {
    'train': os.path.join('train', 'images'),
    'val': os.path.join('valid', 'images'),
    'test': os.path.join('test', 'images'),
    'nc': len(FINAL_CLASS_NAMES),
    'names': FINAL_CLASS_NAMES
}

with open(yaml_path, 'w', encoding='utf-8') as f:
    yaml.dump(yaml_data, f, allow_unicode=True, sort_keys=False)

print(f"✅ '{yaml_path}' 파일 생성 완료!")
print("--- data.yaml 내용 ---")
print(yaml.dump(yaml_data, allow_unicode=True, sort_keys=False))
print("-" * 50)
# Out:
# ✅ 'C:/Users/Admin/work space/2nd/acne_dataset_final\data.yaml' 파일 생성 완료!
# --- data.yaml 내용 ---
# train: train\images
# val: valid\images
# test: test\images
# nc: 8
# names:
# - blackheads
# - comedone
# - cyst
# - fore
# - nodule
# - papule
# - pustule
# - whiteheads
#
# --------------------------------------------------

# %%
print("🚀 모델 학습을 시작합니다...")

# 사전 학습된 YOLOv8n 모델 로드
model = YOLO('yolov8n.pt')

# 모델 학습 실행
results = model.train(
    data=yaml_path,
    epochs=200,      # 필요에 따라 에포크 수 조정
    imgsz=640,
    batch=16,
    project=BASE_DATA_PATH, # 결과 저장 경로
    name='acne_model_8_classes' # 학습 결과가 저장될 폴더 이름
)

print("\n🎉 모든 과정이 완료되었습니다! 학습 결과는 다음 폴더에 저장되었습니다:")
print(os.path.join(BASE_DATA_PATH, 'acne_model_8_classes'))
# Out:
# 🚀 모델 학습을 시작합니다...
# New https://pypi.org/project/ultralytics/8.3.201 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:/Users/Admin/work space/2nd/acne_dataset_final\data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=acne_model_8_classes2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:/Users/Admin/work space/2nd/, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Admin\work space\2nd\acne_model_8_classes2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752872  ultralytics.nn.modules.head.Detect           [8, [64, 128, 256]]
# Model summary: 129 layers, 3,012,408 parameters, 3,012,392 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 10.421.1 MB/s, size: 214.7 KB)
# train: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final\train\labels... 856 images, 224 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 856/856 138.6it/s 6.2s0.1s
# train: New cache created: C:\Users\Admin\work space\2nd\acne_dataset_final\train\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 1, len(boxes) = 2833. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.30.1 ms, read: 0.80.7 MB/s, size: 39.7 KB)
# val: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final\valid\labels... 187 images, 63 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 187/187 78.7it/s 2.4s0.3s
# val: New cache created: C:\Users\Admin\work space\2nd\acne_dataset_final\valid\labels.cache
# Plotting labels to C:\Users\Admin\work space\2nd\acne_model_8_classes2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\Admin\work space\2nd\acne_model_8_classes2
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      2.32G       2.31      4.311      1.818         43        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 28.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.9s1.1ss
#                    all        187        615    0.00681      0.372     0.0415     0.0153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      2.55G      2.158      3.344      1.663         29        640: 100% ━━━━━━━━━━━━ 54/54 2.5it/s 21.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s0.5s
#                    all        187        615      0.416      0.164      0.111     0.0415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      2.76G      2.187      3.031      1.593         64        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 19.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.8s0.9ss
#                    all        187        615      0.364      0.199      0.147     0.0475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      2.77G      2.137      2.883       1.59         46        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 19.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 3.9s0.8s
#                    all        187        615      0.412      0.208      0.181     0.0641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      2.79G      2.132      2.671      1.586         54        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.4s0.9ss
#                    all        187        615      0.368      0.384      0.196     0.0651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      3.25G      2.095      2.653      1.572         34        640: 100% ━━━━━━━━━━━━ 54/54 3.4it/s 16.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.7s0.8s
#                    all        187        615      0.193       0.23      0.153     0.0604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      3.27G      2.083       2.55      1.563         30        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s1.0ss
#                    all        187        615      0.288       0.32      0.208     0.0669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      3.28G      2.119       2.47       1.57         40        640: 100% ━━━━━━━━━━━━ 54/54 2.6it/s 20.5s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.8s1.2ss
#                    all        187        615      0.263      0.305      0.229     0.0919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200       3.3G      2.052       2.32      1.526         14        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 27.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.9it/s 6.4s1.4ss
#                    all        187        615       0.39      0.341      0.263      0.109
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      3.31G       2.02      2.242      1.526         44        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.7s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.9it/s 6.7s1.3ss
#                    all        187        615      0.241      0.374      0.313      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      3.34G      2.034      2.274      1.506         20        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 30.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 4.1s0.5ss
#                    all        187        615        0.3      0.357      0.272      0.086
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      3.35G       2.03       2.22      1.488         39        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s0.6ss
#                    all        187        615      0.343      0.392      0.281      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      3.37G      2.005      2.189      1.491         83        640: 100% ━━━━━━━━━━━━ 54/54 2.1it/s 26.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.9it/s 6.5s0.7ss
#                    all        187        615       0.34      0.324      0.268      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      3.38G      1.997      2.086      1.513        109        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 24.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.5s1.4ss
#                    all        187        615      0.401      0.422      0.347      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      3.41G      2.018      2.025      1.499         32        640: 100% ━━━━━━━━━━━━ 54/54 1.8it/s 29.4s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 8.0s1.6ss
#                    all        187        615      0.396      0.321       0.29       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      3.42G      1.981      2.098        1.5         24        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s
4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.5s1.0s
#                    all        187        615      0.444      0.494      0.419      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      3.73G      1.787      1.469      1.359         19        640: 100% ━━━━━━━━━━━━ 54/54 1.1it/s 50.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 10.7s.1ss
#                    all        187        615       0.64      0.402      0.422      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      3.76G      1.742      1.476      1.333         21        640: 100% ━━━━━━━━━━━━ 54/54 1.4it/s 39.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.2s0.5s
#                    all        187        615      0.417       0.41      0.365      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      3.77G      1.731       1.46      1.332         18        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.3s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 9.4s2.0ss
#                    all        187        615      0.604       0.39      0.365      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      3.79G      1.803      1.468      1.318         31        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s0.5ss
#                    all        187        615      0.433      0.464      0.396      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/200       3.8G      1.768      1.478       1.33         47        640: 100% ━━━━━━━━━━━━ 54/54 1.0it/s 54.3s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 9.9s1.8ss
#                    all        187        615      0.472      0.488      0.448      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      3.83G      1.743      1.429      1.348         52        640: 100% ━━━━━━━━━━━━ 54/54 1.2it/s 45.4s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.8s1.6ss
#                    all        187        615      0.464      0.515      0.482      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      3.84G       1.76      1.442      1.332         41        640: 100% ━━━━━━━━━━━━ 54/54 1.1it/s 50.9s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.3s1.5ss
#                    all        187        615      0.553      0.409      0.419      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      3.86G      1.719       1.44      1.321         12        640: 100% ━━━━━━━━━━━━ 54/54 1.2it/s 43.4s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.4it/s 14.1s2.8s
#                    all        187        615      0.476       0.45      0.429      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      3.87G      1.696      1.437      1.344         23        640: 100% ━━━━━━━━━━━━ 54/54 0.7it/s 1:211.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.4it/s 16.1s3.3s
#                    all        187        615       0.51      0.488      0.453      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/200       3.9G      1.717      1.403      1.316         16        640: 100% ━━━━━━━━━━━━ 54/54 1.4it/s 38.5s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.5it/s 11.8s.2ss
#                    all        187        615      0.528      0.478      0.459      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      3.91G       1.77      1.449      1.322         57        640: 100% ━━━━━━━━━━━━ 54/54 0.8it/s 1:041.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 10.9s.2ss
#                    all        187        615      0.523      0.466       0.42      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      3.93G      1.731      1.378      1.308         46        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.7s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 9.5s1.9ss
#                    all        187        615      0.724      0.363      0.423      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      3.94G      1.704      1.354      1.314         18        640: 100% ━━━━━━━━━━━━ 54/54 0.8it/s 1:080.9s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.7it/s 8.0s1.8ss
#                    all        187        615      0.465      0.522       0.47      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      3.97G      1.677      1.349      1.307         13        640: 100% ━━━━━━━━━━━━ 54/54 0.9it/s 57.8s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.5it/s 11.9s2.4s
#                    all        187        615      0.699      0.415      0.455      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      3.97G       1.71      1.356      1.298         67        640: 100% ━━━━━━━━━━━━ 54/54 0.7it/s 1:170.5sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s0.5s
#                    all        187        615      0.481      0.499      0.446      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/200         4G      1.685      1.349      1.318         28        640: 100% ━━━━━━━━━━━━ 54/54 1.1it/s 48.6s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.9s1.2ss
#                    all        187        615      0.434       0.46      0.374       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      2.57G      1.702      1.323      1.306         57        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 20.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s0.5s
#                    all        187        615      0.448      0.491      0.425      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      2.79G      1.722      1.322      1.299         32        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 20.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.9s1.2ss
#                    all        187        615       0.64      0.442      0.415      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      2.79G      1.688      1.332      1.327         40        640: 100% ━━━━━━━━━━━━ 54/54 2.1it/s 26.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.8s0.5s
#                    all        187        615       0.52       0.44      0.427      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/200      2.79G      1.682      1.255       1.29         40        640: 100% ━━━━━━━━━━━━ 54/54 3.1it/s 17.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.7s0.8s
#                    all        187        615      0.485      0.429      0.433      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/200      2.79G      1.637      1.261      1.276         29        640: 100% ━━━━━━━━━━━━ 54/54 3.5it/s 15.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 4.1s0.8s
#                    all        187        615      0.697      0.416      0.448      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/200      2.79G      1.656      1.271      1.312         72        640: 100% ━━━━━━━━━━━━ 54/54 2.6it/s 20.6s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.0s1.2ss
#                    all        187        615      0.566      0.434      0.414      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/200      2.79G      1.639      1.255      1.271         68        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 20.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.7s0.7s
#                    all        187        615      0.489       0.46      0.426      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/200      3.01G      1.671      1.298      1.277         41        640: 100% ━━━━━━━━━━━━ 54/54 2.0it/s 26.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 5.1s1.1ss
#                    all        187        615      0.554      0.448      0.451      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/200      3.01G      1.643      1.262      1.269         20        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 24.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.5s1.1ss
#                    all        187        615      0.537      0.387      0.421      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/200      3.01G      1.668      1.292      1.275         45        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4it/s 4.3s0.6ss
#                    all        187        615      0.457      0.442      0.365      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/200      3.01G      1.607      1.203      1.264         14        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 19.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s1.0ss
#                    all        187        615      0.504      0.465      0.475      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/200      3.01G      1.648      1.245      1.277         35        640: 100% ━━━━━━━━━━━━ 54/54 2.0it/s 26.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 5.0s1.0ss
#                    all        187        615      0.464      0.438      0.438      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/200      3.01G      1.663      1.282      1.282         55        640: 100% ━━━━━━━━━━━━ 54/54 2.5it/s 21.7s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.2s1.3ss
#                    all        187        615      0.503       0.46      0.403      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/200      3.01G      1.613      1.217      1.284         60        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 20.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.8s1.0ss
#                    all        187        615      0.511      0.418      0.419      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/200      3.01G      1.631       1.19       1.27         46        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.1s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 4.8s0.9ss
#                    all        187        615      0.499      0.462      0.447      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/200      3.01G      1.587      1.171      1.257         51        640: 100% ━━━━━━━━━━━━ 54/54 2.6it/s 20.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s0.5s
#                    all        187        615      0.507      0.448      0.427      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/200      3.35G      1.619      1.214      1.264        157        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 23.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.7s1.1ss
#                    all        187        615      0.565      0.413      0.454      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/200      3.74G      1.654      1.231      1.264         32        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.6s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s0.8ss
#                    all        187        615      0.639      0.431      0.457      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/200      3.75G      1.632      1.213       1.27         39        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 27.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 3.9s0.3s
#                    all        187        615      0.509      0.423      0.436      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/200      3.78G      1.607      1.209      1.249         33        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 24.8s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.8s0.3s
#                    all        187        615      0.474      0.432      0.414      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/200      3.79G      1.584      1.178      1.251         21        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4it/s 4.4s0.3s
#                    all        187        615      0.525      0.473      0.445      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/200      3.81G      1.589      1.165      1.251         19        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.5s0.7s
#                    all        187        615      0.515       0.46       0.44      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/200      3.82G      1.614      1.188      1.238         25        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 28.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.6s0.8ss
#                    all        187        615      0.435      0.457      0.441      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/200      3.84G       1.57       1.15      1.246         58        640: 100% ━━━━━━━━━━━━ 54/54 1.6it/s 33.9s0.3ss
# ...
#     132/200      3.66G      1.422      1.004      1.177         21        640: 100% ━━━━━━━━━━━━ 54/54 1.4it/s 39.8s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.5it/s 11.6s.3ss
#                    all        187        615       0.55      0.447      0.442      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/200      3.69G      1.446       1.02      1.184         32        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 24.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.4it/s 13.9s2.8s
#                    all        187        615      0.575      0.434      0.432      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/200       3.7G       1.47      1.026      1.185         30        640: 100% ━━━━━━━━━━━━ 54/54 1.2it/s 45.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.4it/s 14.3s2.8s
#                    all        187        615      0.492      0.465      0.431       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/200      3.72G       1.43     0.9798      1.162         55        640: 100% ━━━━━━━━━━━━ 54/54 1.1it/s 47.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 8.0s0.6ss
#                    all        187        615      0.504      0.414      0.436      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/200      3.73G      1.447      1.008      1.209         40        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 24.5s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.2s1.5ss
#                    all        187        615      0.592      0.429      0.445      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/200      3.76G      1.447     0.9954       1.17         52        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.5s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.7it/s 8.1s1.7ss
#                    all        187        615      0.556      0.414      0.423      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/200      3.77G      1.404     0.9817      1.171         75        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 31.7s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.7it/s 9.2s2.0ss
#                    all        187        615      0.491      0.434      0.407      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/200      3.79G      1.421      0.997       1.18        103        640: 100% ━━━━━━━━━━━━ 54/54 1.3it/s 40.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.5it/s 12.1s.6ss
#                    all        187        615      0.568      0.426      0.441      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/200       3.8G      1.369     0.9549       1.17         39        640: 100% ━━━━━━━━━━━━ 54/54 1.3it/s 40.3s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.9s0.4s
#                    all        187        615      0.553      0.441      0.444      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/200      3.82G      1.415     0.9583      1.165         39        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 31.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.1s0.4s
#                    all        187        615      0.534       0.44      0.442      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/200      3.83G      1.441     0.9475      1.159         32        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 28.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.1s0.6s
#                    all        187        615      0.506      0.448      0.424      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/200      3.86G      1.361     0.9439      1.171         66        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 31.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4it/s 4.3s0.5s
#                    all        187        615      0.577      0.459      0.429      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/200      3.87G      1.359     0.9355      1.144         64        640: 100% ━━━━━━━━━━━━ 54/54 2.0it/s 27.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.4s
#                    all        187        615       0.49      0.453      0.434      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/200      3.89G      1.382     0.9361      1.169         39        640: 100% ━━━━━━━━━━━━ 54/54 2.5it/s 21.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.1s0.4s
#                    all        187        615      0.501      0.466      0.415      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/200       3.9G      1.405     0.9412      1.142         33        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.6s0.3s
#                    all        187        615      0.538      0.463      0.455      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/200      3.93G      1.354     0.9072      1.134         17        640: 100% ━━━━━━━━━━━━ 54/54 2.7it/s 19.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.4it/s 4.2s0.4s
#                    all        187        615      0.508      0.484      0.448      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/200      3.94G      1.368     0.9073       1.15         29        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s0.3s
#                    all        187        615       0.56      0.471      0.455      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/200      3.96G      1.415     0.9918      1.164         38        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 28.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s0.4s
#                    all        187        615       0.54      0.475      0.447      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/200      3.97G      1.405     0.9154      1.156         47        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 32.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s0.7s
#                    all        187        615      0.541      0.452      0.434      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     151/200      3.99G      1.338     0.9231      1.163         17        640: 100% ━━━━━━━━━━━━ 54/54 1.6it/s 34.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.5s0.7ss
#                    all        187        615      0.539      0.443      0.418      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     152/200         4G      1.366     0.9372      1.145         38        640: 100% ━━━━━━━━━━━━ 54/54 1.5it/s 35.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.2it/s 5.0s1.0ss
#                    all        187        615      0.565      0.458      0.442      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     153/200      2.77G      1.351     0.9084      1.161         16        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 31.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.9s0.6ss
#                    all        187        615      0.565      0.453      0.435      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     154/200      2.77G      1.359      0.903      1.138         32        640: 100% ━━━━━━━━━━━━ 54/54 1.9it/s 28.6s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 5.8s1.2ss
#                    all        187        615      0.533       0.49       0.44      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     155/200      2.77G      1.386     0.9352      1.156        117        640: 100% ━━━━━━━━━━━━ 54/54 2.1it/s 25.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.5s0.9ss
#                    all        187        615      0.537      0.477      0.447      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     156/200      2.77G      1.355     0.9222      1.134         62        640: 100% ━━━━━━━━━━━━ 54/54 1.7it/s 31.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.1s1.2ss
#                    all        187        615      0.535      0.486      0.431      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     157/200      2.77G      1.334     0.9042      1.138         16        640: 100% ━━━━━━━━━━━━ 54/54 2.3it/s 23.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0it/s 6.1s1.2ss
#                    all        187        615      0.527       0.46      0.431      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     158/200      2.77G      1.359      0.918      1.136         38        640: 100% ━━━━━━━━━━━━ 54/54 2.2it/s 25.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6it/s 3.8s0.7ss
#                    all        187        615      0.488      0.481      0.438      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     159/200         3G      1.327     0.8829      1.126         42        640: 100% ━━━━━━━━━━━━ 54/54 2.6it/s 20.9s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.8it/s 7.2s1.5ss
#                    all        187        615       0.49      0.464      0.433      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     160/200         3G      1.358     0.8932      1.141         22        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.2s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.2s0.5ss
#                    all        187        615      0.549       0.49      0.447      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     161/200         3G      1.324     0.8931      1.136         46        640: 100% ━━━━━━━━━━━━ 54/54 2.8it/s 19.4s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.1it/s 5.4s1.1ss
#                    all        187        615      0.532      0.464      0.418      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     162/200         3G      1.302     0.8781      1.103         21        640: 100% ━━━━━━━━━━━━ 54/54 2.4it/s 22.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.4s
#                    all        187        615      0.589      0.438      0.432      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     163/200         3G      1.302     0.8667      1.107         30        640: 100% ━━━━━━━━━━━━ 54/54 2.8it/s 19.0s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.3it/s 4.7s0.9ss
#                    all        187        615      0.565       0.46      0.431      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     164/200         3G      1.293     0.8772      1.134         65        640: 100% ━━━━━━━━━━━━ 54/54 2.5it/s 22.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.8s0.6s
#                    all        187        615      0.546      0.445      0.431      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     165/200         3G      1.317     0.8592      1.103         65        640: 100% ━━━━━━━━━━━━ 54/54 2.5it/s 21.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.6it/s 9.6s1.9ss
#                    all        187        615      0.521      0.502      0.437      0.182
# EarlyStopping: Training stopped early as no improvement observed in last 100 epochs. Best results observed at epoch 65, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 165 epochs completed in 1.615 hours.
# Optimizer stripped from C:\Users\Admin\work space\2nd\acne_model_8_classes2\weights\last.pt, 6.3MB
# Optimizer stripped from C:\Users\Admin\work space\2nd\acne_model_8_classes2\weights\best.pt, 6.3MB
#
# Validating C:\Users\Admin\work space\2nd\acne_model_8_classes2\weights\best.pt...
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.5it/s 12.2s2.5s
#                    all        187        615      0.459      0.515       0.48      0.199
#               comedone         31         96       0.54      0.552      0.578      0.246
#                   cyst         18         20      0.403       0.75      0.575      0.257
#                 nodule         28         35      0.655      0.543      0.544      0.274
#                 papule         33        419      0.435      0.537      0.497      0.197
#                pustule         11         20       0.37       0.55      0.482      0.178
#             whiteheads          9         25       0.35       0.16      0.203     0.0431
# Speed: 1.6ms preprocess, 4.6ms inference, 0.0ms loss, 15.9ms postprocess per image
# Results saved to C:\Users\Admin\work space\2nd\acne_model_8_classes2
#
# 🎉 모든 과정이 완료되었습니다! 학습 결과는 다음 폴더에 저장되었습니다:
# C:/Users/Admin/work space/2nd/acne_model_8_classes

# %%
from ultralytics import YOLO
import os

# 1. 가장 성능이 좋았던 모델 파일 경로
MODEL_PATH = 'C:/Users/Admin/work space/2nd/acne_model_8_classes/weights/best.pt'

# 2. 학습 시 생성된 data.yaml 파일 경로
DATA_YAML_PATH = 'C:/Users/Admin/work space/2nd/acne_dataset_final/data.yaml'

# 모델 로드
model = YOLO(MODEL_PATH)

# 모델 성능 검증 (test 데이터셋 사용)
# split='val'로 변경하면 validation 데이터셋으로 검증합니다.
print("🚀 테스트 데이터셋으로 모델 성능을 검증합니다...")
metrics = model.val(data=DATA_YAML_PATH, split='test', imgsz=640)

print("\n--- 최종 성능 지표 ---")
print(f"mAP50-95 (평균 IoU 0.5~0.95): {metrics.box.map:.4f}")
print(f"mAP50 (IoU 0.5 기준): {metrics.box.map50:.4f}")
print(f"mAP75 (IoU 0.75 기준): {metrics.box.map75:.4f}")
# Out:
# 🚀 테스트 데이터셋으로 모델 성능을 검증합니다...
# Ultralytics 8.3.200  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 2.21.3 MB/s, size: 16.4 KB)
# val: Scanning C:\Users\Admin\work space\2nd\acne_dataset_final\test\labels... 123 images, 35 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 123/123 213.4it/s 0.6s0.1s
# val: New cache created: C:\Users\Admin\work space\2nd\acne_dataset_final\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.2it/s 6.5s0.5ss
#                    all        123        461      0.477      0.451      0.419      0.174
#               comedone         24         86        0.6      0.605      0.599      0.253
#                   cyst         18         19      0.669      0.639      0.701       0.28
#                 nodule         19         19      0.622      0.579      0.493      0.252
#                 papule         18        264       0.36      0.595      0.442      0.169
#                pustule         10         44      0.225      0.114      0.122     0.0436
#             whiteheads          7         29      0.386      0.172      0.157     0.0432
# Speed: 0.4ms preprocess, 18.8ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to C:\Users\Admin\work space\2nd\runs\detect\val9
#
# --- 최종 성능 지표 ---
# mAP50-95 (평균 IoU 0.5~0.95): 0.1736
# mAP50 (IoU 0.5 기준): 0.4193
# mAP75 (IoU 0.75 기준): 0.1140

# %%
import matplotlib.pyplot as plt
import cv2
import os

# 학습 결과가 저장된 폴더 경로
RESULTS_DIR = 'C:/Users/Admin/work space/2nd/acne_model_8_classes/'

# (1) 혼동 행렬 (Confusion Matrix) 시각화
# 모델이 어떤 클래스를 다른 클래스로 착각하는지 보여줍니다.
# 대각선에 값이 집중될수록 좋은 모델입니다.
img_cm_path = os.path.join(RESULTS_DIR, 'confusion_matrix.png')
if os.path.exists(img_cm_path):
    img_cm = cv2.imread(img_cm_path)
    plt.figure(figsize=(12, 10))
    plt.imshow(cv2.cvtColor(img_cm, cv2.COLOR_BGR2RGB))
    plt.title('Confusion Matrix', fontsize=20)
    plt.axis('off')
    plt.show()
else:
    print(f"'{img_cm_path}' 파일을 찾을 수 없습니다.")

# (2) 검증 데이터 예측 결과 시각화
# Validation 데이터셋의 일부 이미지에 대한 예측 결과입니다.
img_pred_path = os.path.join(RESULTS_DIR, 'val_batch0_pred.jpg')
if os.path.exists(img_pred_path):
    img_pred = cv2.imread(img_pred_path)
    plt.figure(figsize=(15, 10))
    plt.imshow(cv2.cvtColor(img_pred, cv2.COLOR_BGR2RGB))
    plt.title('Validation Predictions', fontsize=20)
    plt.axis('off')
    plt.show()
else:
    print(f"'{img_pred_path}' 파일을 찾을 수 없습니다.")
